# %%
import pandas as pd

produtos_df = pd.read_csv(r"Contoso - Cadastro Produtos.csv", sep=';', encoding='latin1')
vendas_df = pd.read_csv(r'Contoso - Vendas - 2017.csv', sep=';')
clientes_df = pd.read_csv(r'Contoso - Clientes.csv', sep=';', encoding='latin1')
lojas_df = pd.read_csv(r'Contoso - Lojas.csv', sep=';', encoding='latin1')

#Renomeando
produtos_df = produtos_df.rename(columns={'ÿNome do Produto':'Nome do Produto'})
clientes_df = clientes_df.rename(columns={'ÿID Cliente':'ID Cliente'})
lojas_df = lojas_df.rename(columns={'ÿID Loja':'ID Loja'})

#Simplificando
produtos_df = produtos_df[['ID Produto', 'Nome do Produto']]
clientes_df = clientes_df[['ID Cliente', 'E-mail']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]

#Mesclando
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente').rename(columns={'E-mail':'E-mail do Cliente'})
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')

# %% [markdown]
# Qual a % das vendas que foi devolvido?

# %%
qntd_vendida = vendas_df['Quantidade Vendida'].sum()
qntd_devolvida = vendas_df['Quantidade Devolvida'].sum()

print('{:.2%}'.format(qntd_devolvida / qntd_vendida))
# Out:
# 1.17%

# %% [markdown]
# Para fazer a mesma análise apenas com uma loja? Queremos filtrar os itens da Loja Contoso Europe Online e saber a % de devolução dessa loja.

# %%
vendas_lc_europeon =  vendas_df[vendas_df['ID Loja'] == 306]
display(vendas_lc_europeon)

qntd_vendida = vendas_lc_europeon['Quantidade Vendida'].sum()
qntd_devolvida = vendas_lc_europeon['Quantidade Devolvida'].sum()

print('{:.2%}'.format(qntd_devolvida / qntd_vendida))
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 98                   99    01/01/2017    03/01/2017         2      306
# 165                 166    01/01/2017    02/01/2017         1      306
# 166                 167    01/01/2017    05/01/2017         4      306
# 186                 187    01/01/2017    06/01/2017         5      306
# 198                 199    01/01/2017    03/01/2017         2      306
# ...                 ...           ...           ...       ...      ...
# 980579           980580    31/12/2017    06/01/2018         6      306
# 980580           980581    31/12/2017    01/01/2018         1      306
# 980581           980582    31/12/2017    31/12/2017         0      306
# 980582           980583    31/12/2017    03/01/2018         3      306
# 980632           980633    31/12/2017    31/12/2017         0      306
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...
